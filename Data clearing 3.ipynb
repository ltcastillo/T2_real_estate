# %%
import numpy as np
import pandas as pd
from pathlib import Path
from collections import Counter

# %%
file_path = Path('zillow_BayArea_ZipCodes.csv')
value_df = pd.read_csv(file_path)
value_df.head()
# Out:
#    regionid  sizerank  regionname regiontype statename state           city  \
# 0     97564        13       94109        Zip        CA    CA  San Francisco
# 1     97771        40       94565        Zip        CA    CA      Pittsburg
# 2     97711        88       94501        Zip        CA    CA        Alameda
# 3     97565        94       94110        Zip        CA    CA  San Francisco
# 4     97764       135       94558        Zip        CA    CA           Napa
#
#                            metro            countyname  1/31/1996  ...  \
# 0  San Francisco-Oakland-Hayward  San Francisco County   328656.0  ...
# 1  San Francisco-Oakland-Hayward   Contra Costa County        NaN  ...
# 2  San Francisco-Oakland-Hayward        Alameda County   183472.0  ...
# 3  San Francisco-Oakland-Hayward  San Francisco County   285484.0  ...
# 4                           Napa           Napa County   182930.0  ...
#
#    11/30/2019  12/31/2019  1/31/2020  2/29/2020  3/31/2020  4/30/2020  \
# 0     1187876     1199675    1203184    1206697    1204845    1205072
# 1      565022      567631     566696     567253     569358     573486
# 2     1047236     1055178    1067691    1076863    1080996    1080102
# 3     1604555     1615289    1620314    1623580    1621014    1621355
# 4      694770      693290     691986     690989     692339     695810
#
#    5/31/2020  6/30/2020  7/31/2020  8/31/2020
# 0    1199464    1192642    1188599    1186661
# 1     574099     575338     577656     584991
# 2    1076650    1074598    1074008    1081110
# 3    1616660    1611109    1607900    1612066
# 4     699622     702518     707692     714354
#
# [5 rows x 305 columns]

# %%
value_df1=value_df[["regionname","city","8/31/1996","8/31/1997","8/31/1998","8/31/1999",
                    "8/31/2000","8/31/2001","8/31/2002","8/31/2003","8/31/2004",
                    "8/31/2005","8/31/2006","8/31/2007","8/31/2008","8/31/2009",
                    "8/31/2010","8/31/2016","8/31/2011","8/31/2012","8/31/2013","8/31/2014",
                    "8/31/2015","8/31/2016","8/31/2017","8/31/2018","8/31/2019","8/31/2020"]]
value_df1.head()
# Out:
#    regionname           city  8/31/1996  8/31/1997  8/31/1998  8/31/1999  \
# 0       94109  San Francisco   326085.0   353934.0   406629.0   471674.0
# 1       94565      Pittsburg        NaN        NaN        NaN        NaN
# 2       94501        Alameda   179692.0   191751.0   216239.0   236873.0
# 3       94110  San Francisco   280842.0   316693.0   363648.0   426798.0
# 4       94558           Napa   177248.0   185732.0   200201.0   218762.0
#
#    8/31/2000  8/31/2001  8/31/2002  8/31/2003  ...  8/31/2011  8/31/2012  \
# 0   580761.0   679960.0   645122.0   677438.0  ...   735934.0   797920.0
# 1        NaN        NaN        NaN        NaN  ...   287529.0   329455.0
# 2   290329.0   341680.0   362073.0   399552.0  ...   472733.0   496718.0
# 3   539618.0   631868.0   646629.0   675601.0  ...   798767.0   873495.0
# 4   262226.0   312395.0   346277.0   402110.0  ...   379944.0   398407.0
#
#    8/31/2013  8/31/2014  8/31/2015  8/31/2016  8/31/2017  8/31/2018  \
# 0   934134.0   979067.0  1116705.0  1089613.0  1134028.0    1196188
# 1   393662.0   435774.0   472300.0   508109.0   528843.0     573886
# 2   633991.0   682303.0   771039.0   839699.0   906881.0    1015675
# 3  1048164.0  1225162.0  1394674.0  1395647.0  1482253.0    1632966
# 4   485951.0   540970.0   583670.0   627115.0   654739.0     693627
#
#    8/31/2019  8/31/2020
# 0    1172905    1186661
# 1     568129     584991
# 2    1043225    1081110
# 3    1585787    1612066
# 4     699242     714354
#
# [5 rows x 28 columns]

# %%
value_df2=value_df1.dropna()

# %%
value_df2.dtypes
# Out:
# regionname      int64
# city           object
# 8/31/1996     float64
# 8/31/1997     float64
# 8/31/1998     float64
# 8/31/1999     float64
# 8/31/2000     float64
# 8/31/2001     float64
# 8/31/2002     float64
# 8/31/2003     float64
# 8/31/2004     float64
# 8/31/2005     float64
# 8/31/2006     float64
# 8/31/2007     float64
# 8/31/2008     float64
# 8/31/2009     float64
# 8/31/2010     float64
# 8/31/2016     float64
# 8/31/2011     float64
# 8/31/2012     float64
# 8/31/2013     float64
# 8/31/2014     float64
# 8/31/2015     float64
# 8/31/2016     float64
# 8/31/2017     float64
# 8/31/2018       int64
# 8/31/2019       int64
# 8/31/2020       int64
# 202008        float64
# 201908        float64
# 201808        float64
# dtype: object

# %%
value_df2['202008']=value_df2['8/31/2020']/value_df2['8/31/2019']-1
value_df2['201908']=value_df2['8/31/2019']/value_df2['8/31/2018']-1
value_df2['201808']=value_df2['8/31/2018']/value_df2['8/31/2017']-1
# Out:
# C:\Users\Jane\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\Jane\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Jane\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
value_df2['201708']=value_df2['8/31/2017']/value_df2['8/31/2016']-1
value_df2['201608']=value_df2['8/31/2016']/value_df2['8/31/2015']-1
value_df2['201508']=value_df2['8/31/2015']/value_df2['8/31/2014']-1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-2131032b5a12> in <module>
# ----> 1 value_df2['201708']=value_df2['8/31/2017']/value_df2['8/31/2016']-1
#       2 value_df2['201608']=value_df2['8/31/2016']/value_df2['8/31/2015']-1
#       3 value_df2['201508']=value_df2['8/31/2015']/value_df2['8/31/2014']-1
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\ops\__init__.py in f(self, other, axis, level, fill_value)
#     774             pass_op = pass_op if not is_logical else op
#     775             return _combine_series_frame(
# --> 776                 self, other, pass_op, fill_value=fill_value, axis=axis, level=level
#     777             )
#     778         else:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\ops\__init__.py in _combine_series_frame(self, other, func, fill_value, axis, level)
#     614
#     615     axis = self._get_axis_number(axis)
# --> 616     left, right = self.align(other, join="outer", axis=axis, level=level, copy=False)
#     617     if axis == 0:
#     618         new_data = left._combine_match_index(right, func)
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\frame.py in align(self, other, join, axis, level, copy, fill_value, method, limit, fill_axis, broadcast_axis)
#    3832             limit=limit,
#    3833             fill_axis=fill_axis,
# -> 3834             broadcast_axis=broadcast_axis,
#    3835         )
#    3836
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\generic.py in align(self, other, join, axis, level, copy, fill_value, method, limit, fill_axis, broadcast_axis)
#    8484                 method=method,
#    8485                 limit=limit,
# -> 8486                 fill_axis=fill_axis,
#    8487             )
#    8488         else:  # pragma: no cover
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\generic.py in _align_series(self, other, join, axis, level, copy, fill_value, method, limit, fill_axis)
#    8601                 if not self.columns.equals(other.index):
#    8602                     join_index, lidx, ridx = self.columns.join(
# -> 8603                         other.index, how=join, level=level, return_indexers=True
#    8604                     )
#    8605
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\indexes\base.py in join(self, other, how, level, return_indexers, sort)
#    3293             this = self.astype("O")
#    3294             other = other.astype("O")
# -> 3295             return this.join(other, how=how, return_indexers=return_indexers)
#    3296
#    3297         _validate_join_method(how)
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\indexes\base.py in join(self, other, how, level, return_indexers, sort)
#    3304             if self.is_monotonic and other.is_monotonic:
#    3305                 return self._join_monotonic(
# -> 3306                     other, how=how, return_indexers=return_indexers
#    3307                 )
#    3308             else:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\indexes\base.py in _join_monotonic(self, other, how, return_indexers)
#    3619                 join_index, lidx, ridx = self._inner_indexer(sv, ov)
#    3620             elif how == "outer":
# -> 3621                 join_index, lidx, ridx = self._outer_indexer(sv, ov)
#    3622             join_index = self._wrap_joined_index(join_index, other)
#    3623
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\indexes\base.py in _outer_indexer(self, left, right)
#     240
#     241     def _outer_indexer(self, left, right):
# --> 242         return libjoin.outer_join_indexer(left, right)
#     243
#     244     _typ = "index"
#
# pandas\_libs\join.pyx in pandas._libs.join.outer_join_indexer()
#
# TypeError: '<' not supported between instances of 'str' and 'int'
